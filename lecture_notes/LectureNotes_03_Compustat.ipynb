# %% [markdown]
# # Big Data in Finance: Part IV <BR><BR> Lecture Notes 3: Compustat
#
# **Instructor** <BR>
# Kirsten Burr, kburr26@gsb.columbia.edu
#
# **TA's:** <BR>
# Luman Zou, lz2867@columbia.edu <BR>
# Yifan Wan, YWan26@gsb.columbia.edu
#
# <sub> Credit: lecture notes adapted from notes developed by Lira Mota

# %% [markdown]
# ## Compustat
#
# In this section we are going to:
# 1. Download a set of US firm's annual fundamentals;
# 2. Understand how the data is organized:
#     1. Primary keys;
#     2. Secondary keys;
#     3. Data frequency;
#     4. Others.
# 2. Clean the data;
# 3. Construct important variables:
#     1. Book Equity Value
#     2. Asset Growth
#     3. Operational Profitability

# %% [markdown]
# ### How is the fundamentals data organized?
#
# * We can display all tables in "comp" library.
# * We are going to focus on the "funda" table: annual fundamentals.
# * Others that are interesting to know: "namesd"

# %% [markdown]
# ### Set Up

# %%
# %matplotlib inline 

#%% Packages 
import wrds
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 6]

import time
from time import strptime, strftime

# Setups
pd.set_option("display.max_rows", 200) # max number or rows to be displayed

# %%
#%% Set WRDS Connection
db = wrds.Connection(wrds_username='khardnett') # make sure to configure wrds connector before hand.
# Out:
# Loading library list...
# Done

# %% [markdown]
# #### All tables in comp

# %%
compm_tables = db.list_tables(library="comp")

# %%
 pd.DataFrame({'tables':compm_tables}).head(100) # Transform libs to a Pandas data frame to have a better display.
# Out:
#              tables
# 0          aco_amda
# 1          aco_imda
# 2       aco_indfnta
# 3       aco_indfntq
# 4     aco_indfntytd
# 5        aco_indsta
# 6        aco_indstq
# 7      aco_indstytd
# 8        aco_notesa
# 9        aco_notesq
# 10      aco_notessa
# 11     aco_notesytd
# 12       aco_pnfnda
# 13       aco_pnfndq
# 14     aco_pnfndytd
# 15       aco_pnfnta
# 16       aco_pnfntq
# 17     aco_pnfntytd
# 18       aco_transa
# 19       aco_transq
# 20      aco_transsa
# 21     aco_transytd
# 22         adsprate
# 23        asec_amda
# 24        asec_imda
# 25      asec_notesa
# 26      asec_notesq
# 27      asec_transa
# 28      asec_transq
# 29    bank_aacctchg
# 30     bank_adesind
# 31       bank_afnd1
# 32       bank_afnd2
# 33     bank_afnddc1
# 34     bank_afnddc2
# 35     bank_afntind
# 36       bank_funda
# 37  bank_funda_fncd
# 38       bank_fundq
# 39  bank_fundq_fncd
# 40    bank_iacctchg
# 41     bank_idesind
# 42       bank_ifndq
# 43     bank_ifndytd
# 44       bank_ifntq
# 45     bank_ifntytd
# 46       bank_names
# 47      bank_namesq
# 48            chars
# 49      co_aacctchg
# 50        co_aaudit
# 51       co_acthist
# 52       co_adesind
# 53       co_adjfact
# 54         co_afnd1
# 55         co_afnd2
# 56       co_afnddc1
# 57       co_afnddc2
# 58      co_afntind1
# 59      co_afntind2
# 60       co_ainvval
# 61          co_amkt
# 62      co_busdescl
# 63        co_cotype
# 64      co_filedate
# 65       co_fortune
# 66          co_hgic
# 67      co_iacctchg
# 68        co_iaudit
# 69       co_idesind
# 70         co_ifndq
# 71        co_ifndsa
# 72       co_ifndytd
# 73         co_ifntq
# 74        co_ifntsa
# 75       co_ifntytd
# 76          co_imkt
# 77      co_industry
# 78          co_ipcd
# 79         co_mthly
# 80       co_offtitl
# 81          company
# 82         currency
# 83         dd_group
# 84    dd_group_xref
# 85          dd_item
# 86       dd_package
# 87       ecind_desc
# 88        ecind_mth
# 89         exrt_dly
# 90         exrt_mth
# 91          filings
# 92            funda
# 93       funda_fncd
# 94            fundq
# 95       fundq_fncd
# 96          g_chars
# 97      g_co_aaudit
# 98     g_co_adesind
# 99       g_co_afnd1

# %% [markdown]
# #### All variables in comp.funda

# %%
db.describe_table(library="comp", table="funda") # fundq: Compustat fundamentals table quarterly update
# Out:
# Approximately 933591 rows in comp.funda.
#          name  nullable         type  \
# 0       gvkey      True   VARCHAR(7)
# 1    datadate      True         DATE
# 2       fyear      True      INTEGER
# 3      indfmt      True  VARCHAR(13)
# 4      consol      True   VARCHAR(3)
# ..        ...       ...          ...
# 944        au      True   VARCHAR(9)
# 945      auop      True   VARCHAR(9)
# 946    auopic      True   VARCHAR(2)
# 947     ceoso      True   VARCHAR(2)
# 948     cfoso      True   VARCHAR(2)
#
#                                                comment
# 0                                   Global Company Key
# 1                                            Data Date
# 2                                   Data Year - Fiscal
# 3                                      Industry Format
# 4    Level of Consolidation - Company Annual Descri...
# ..                                                 ...
# 944                                            Auditor
# 945                                    Auditor Opinion
# 946                 Auditor Opinion - Internal Control
# 947          Chief Executive Officer SOX Certification
# 948          Chief Financial Officer SOX Certification
#
# [949 rows x 4 columns]

# %% [markdown]
# ##### Where to check variable definitions?
# 1. [Compustat Data Items](https://wrds-www.wharton.upenn.edu/pages/get-data/compustat-capital-iq-standard-poors/compustat/north-america-daily/fundamentals-annual/)
# 2. WRDS website: go to the (?) sign
# 3. What if we want to replicate a paper that says:
#
#    "Earnings (E) is income before extraordinary items (Item 18) plus income statement deferred taxes (Item 50) minus preferred dividends (Item 19), if earnings are positive;" [Baker and Wurgler, JF 2006](https://onlinelibrary.wiley.com/doi/epdf/10.1111/j.1540-6261.2006.00885.x)
#
#     * All previous documentation does not contain ITEM numbers
#     * These are the legacy CST item numbers
#     * You can find item reference [here](https://www.crsp.org/products/documentation/annual-data-industrial).

# %% [markdown]
# **Objective**
#
# Create a data frame with company fundamentals necessary to replicate FF 2015:
#
# 1. Book Equity (BE)
# 2. Operating Profits (OP)
# 3. Investment (INV)

# %% [markdown]
# ## Choose variables of interest

# %% [markdown]
# Compustat XpressFeed Variables 1/5:
# * AT      = Total Assets
# * CAPX    = Capital Expenditures
# * CEQ     = Common/Ordinary Equity - Total
# * COGS    = Cost of Goods Sold
# * CSHO    = Common Shares Outstanding
# * DLC     = Debt in Current Liabilities
# * DLCCH   = Current Debt - Changes
# * DLTT    = Long-Term Debt - Total

# %% [markdown]
# Compustat XpressFeed Variables 2/5:
# * DP      = Depreciation and Amortization
# * DVC     = Divdends common/ordinary
# * DVP     = Dividends - Preferred/Preference
# * GP      = Gross Profits
# * IB      = Income Before Extraordinary Items
# * ICAPT   = Invested Capital - Total
# * ITCB    = Investment Tax Credit (Balance Sheet)
# * LT      = Total Liabilities

# %% [markdown]
# Compustat XpressFeed Variables 3/5:
# * MIB     = Minority Interest (Balance Sheet)
# * NAICS   = North American Industrial Classification System Variable Name
# * NAICSH  = North American Industry Classification Codes - Historical Company Variable Name
# * NI      = Net Income
# * PPEGT   = "Property, Plant and Equipment - Total (Gross)"
# * PRBA    = Postretirement Benefit Assets (from separate pension annual file)
# * PRSTKCC = Purchase of Common Stock (Cash Flow)
# * PSTKRV  = Preferred Stock Redemption Value

# %% [markdown]
# Compustat XpressFeed Variables 4/5:
# * PSTK    = Preferred/Preference Stock (Capital) - Total (kd: = par?)
# * PSTKL   = Preferred Stock Liquidating Value
# * PSTKRV  = Preferred Stock Liquidating Value
# * RE      = Retained Earnings
# * REVT    = Revenue - Total
# * SALE    = Sales/Turnover Net
# * SEQ     = Shareholders Equity
# * SIC     = Standard Industrial Classification Code

# %% [markdown]
# Compustat XpressFeed Variables 5/5:
# * TXDB    = Deferred Taxes Balance Sheet
# * TXDI    = Income Taxes - Deferred
# * TXDITC  = Deferred Taxes and Investment Tax Credit
# * WCAPCH  = Working Capital Change - Total
# * XINT    = Interest and Related Expense - Total
# * XLR     = Staff Expense - Total
# * XRD     = Research and Development Expense
# * XSGAQ   = Selling, General and Administrative Expenses (millions)

# %% [markdown]
# ## Download Compustat FUNDA

# %%
fund_table = 'funda'

varlist = ['conm', 'tic', 'cusip','fyear', 'fyr', 'at','capx', 'ceq', 'cogs', 'csho', 'dlc', 'dlcch','dltt', 'dp', 'ib', 'itcb', 
           'lt', 'mib', 'naicsh', 'ni', 'prstkcc', 'pstk', 'pstkl', 'pstkrv', 're', 'revt', 'sale', 
           'seq', 'sich', 'txdb', 'txdi', 'txditc', 'wcapch', 'xint', 'xlr', 'xrd', 'xsga']


query = """SELECT gvkey, datadate, {}
           FROM comp.{}
           WHERE datafmt = 'STD'
           AND popsrc = 'D'
           AND indfmt = 'INDL'
           AND consol = 'C'
           AND fyear>=1980;""".format(", ".join(varlist), fund_table)

compa = db.raw_sql(query, date_cols=['datadate'])

del(fund_table, varlist, query)

# %% [markdown]
# Always look at your data

# %%
# Gerneral Look
compa.head()
# Out:
#     gvkey   datadate                     conm    tic      cusip  fyear  fyr  \
# 0  001001 1980-12-31  A & M FOOD SERVICES INC  AMFD.  000165100   1980   12
# 1  001001 1981-12-31  A & M FOOD SERVICES INC  AMFD.  000165100   1981   12
# 2  001001 1982-12-31  A & M FOOD SERVICES INC  AMFD.  000165100   1982   12
# 3  001003 1983-12-31    A.A. IMPORTING CO INC   ANTQ  000354100   1983   12
# 4  001001 1983-12-31  A & M FOOD SERVICES INC  AMFD.  000165100   1983   12
#
#        at   capx    ceq  ...    seq  sich  txdb   txdi  txditc  wcapch   xint  \
# 0     NaN    NaN    NaN  ...    NaN   NaN   NaN    NaN     NaN     NaN    NaN
# 1     NaN    NaN    NaN  ...    NaN   NaN   NaN    NaN     NaN     NaN    NaN
# 2     NaN    NaN    NaN  ...    NaN   NaN   NaN    NaN     NaN     NaN    NaN
# 3   8.529  0.146  6.095  ...  6.095   NaN   0.0  0.000     0.0     NaN  0.130
# 4  14.080  3.367  7.823  ...  7.823   NaN   0.0  0.144     0.0   3.618  0.763
#
#    xlr  xrd    xsga
# 0  NaN  NaN     NaN
# 1  NaN  NaN     NaN
# 2  NaN  NaN     NaN
# 3  NaN  NaN   3.186
# 4  NaN  0.0  16.435
#
# [5 rows x 39 columns]

# %%
# Have a sense about missings
compa['at'].isnull().mean()*100
# Out:
# 18.932106341941218

# %%
compa.gvkey.nunique()
# Out:
# 44588

# %%
compa.groupby('fyear').gvkey.nunique()
# Out:
# fyear
# 1980     6889
# 1981     7058
# 1982     7685
# 1983     7996
# 1984     8243
# 1985     8599
# 1986     9017
# 1987     9225
# 1988     9333
# 1989     9343
# 1990     9571
# 1991     9966
# 1992    10705
# 1993    11482
# 1994    11899
# 1995    12492
# 1996    12624
# 1997    12437
# 1998    12554
# 1999    12531
# 2000    12093
# 2001    11584
# 2002    11253
# 2003    11067
# 2004    10901
# 2005    10857
# 2006    10878
# 2007    10875
# 2008    10687
# 2009    10642
# 2010    10861
# 2011    11266
# 2012    11668
# 2013    11715
# 2014    11550
# 2015    11446
# 2016    11368
# 2017    11289
# 2018    11375
# 2019    11625
# 2020    11922
# 2021    12271
# 2022    12578
# 2023    12633
# 2024    12745
# 2025     9362
# Name: gvkey, dtype: int64

# %% [markdown]
# ## Data Consistency

# %% [markdown]
# ### Primary Keys
#
#
# * We are looking at Annual data
# * Logic says that that we should have one company (gvkey) per year (fyear)
# * But remember, the primary key for funda is (gvkey and datadate)
# * Question: Can a firm have two datadate for the same year?

# %%
# It is always good to check if we have the right PK
compa.duplicated(['gvkey', 'datadate']).sum()
# Out:
# 0

# %%
# Is (gvkey, fyear) PK?
compa[compa.duplicated(['gvkey', 'fyear'])]
# Out:
#          gvkey   datadate                       conm   tic      cusip  fyear  \
# 67686   006557 1982-12-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102   1982
# 67688   006557 1983-12-31  LAIDLAW INTERNATIONAL INC  LI.3  50730R102   1983
# 314877  039310 2021-01-31    VICTORIAS SECRET AND CO  VSCO  926400102   2020
# 364075  066552 2010-12-31   LIMITLESS X HOLDINGS INC  LIMX  090622309   2010
# 364077  066552 2011-12-31   LIMITLESS X HOLDINGS INC  LIMX  090622309   2011
# 364079  066552 2012-12-31   LIMITLESS X HOLDINGS INC  LIMX  090622309   2012
# 364081  066552 2013-12-31   LIMITLESS X HOLDINGS INC  LIMX  090622309   2013
# 364083  066552 2014-12-31   LIMITLESS X HOLDINGS INC  LIMX  090622309   2014
# 364085  066552 2015-12-31   LIMITLESS X HOLDINGS INC  LIMX  090622309   2015
# 364087  066552 2016-12-31   LIMITLESS X HOLDINGS INC  LIMX  090622309   2016
# 364089  066552 2017-12-31   LIMITLESS X HOLDINGS INC  LIMX  090622309   2017
# 364091  066552 2018-12-31   LIMITLESS X HOLDINGS INC  LIMX  090622309   2018
# 364093  066552 2019-12-31   LIMITLESS X HOLDINGS INC  LIMX  090622309   2019
#
#         fyr      at   capx    ceq  ...    seq    sich  txdb  txdi  txditc  \
# 67686    12     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 67688    12     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 314877    1  4229.0  127.0  891.0  ...  891.0  5621.0  19.0 -64.0    19.0
# 364075   12     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 364077   12     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 364079   12     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 364081   12     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 364083   12     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 364085   12     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 364087   12     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 364089   12     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 364091   12     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
# 364093   12     NaN    NaN    NaN  ...    NaN     NaN   NaN   NaN     NaN
#
#         wcapch  xint  xlr  xrd    xsga
# 67686      NaN   NaN  NaN  NaN     NaN
# 67688      NaN   NaN  NaN  NaN     NaN
# 314877     NaN   6.0  NaN  0.0  1621.0
# 364075     NaN   NaN  NaN  NaN     NaN
# 364077     NaN   NaN  NaN  NaN     NaN
# 364079     NaN   NaN  NaN  NaN     NaN
# 364081     NaN   NaN  NaN  NaN     NaN
# 364083     NaN   NaN  NaN  NaN     NaN
# 364085     NaN   NaN  NaN  NaN     NaN
# 364087     NaN   NaN  NaN  NaN     NaN
# 364089     NaN   NaN  NaN  NaN     NaN
# 364091     NaN   NaN  NaN  NaN     NaN
# 364093     NaN   NaN  NaN  NaN     NaN
#
# [13 rows x 39 columns]

# %%
# Example of a company that have two reports for the same year
compa.loc[compa.gvkey=='006557',['gvkey','datadate','fyear','fyr','conm', 'at']]
# Out:
#         gvkey   datadate  fyear  fyr                       conm        at
# 67302  006557 1990-08-31   1990    8  LAIDLAW INTERNATIONAL INC  3894.939
# 67498  006557 1991-08-31   1991    8  LAIDLAW INTERNATIONAL INC  3595.316
# 67515  006557 1992-08-31   1992    8  LAIDLAW INTERNATIONAL INC  3658.935
# 67533  006557 1993-08-31   1993    8  LAIDLAW INTERNATIONAL INC  3575.082
# 67647  006557 1994-08-31   1994    8  LAIDLAW INTERNATIONAL INC  3633.200
# 67683  006557 1980-08-31   1980    8  LAIDLAW INTERNATIONAL INC   201.266
# 67684  006557 1981-08-31   1981    8  LAIDLAW INTERNATIONAL INC   242.081
# 67685  006557 1982-08-31   1982    8  LAIDLAW INTERNATIONAL INC   251.360
# 67686  006557 1982-12-31   1982   12  LAIDLAW INTERNATIONAL INC       NaN
# 67687  006557 1983-08-31   1983    8  LAIDLAW INTERNATIONAL INC   328.891
# 67688  006557 1983-12-31   1983   12  LAIDLAW INTERNATIONAL INC       NaN
# 67689  006557 1984-08-31   1984    8  LAIDLAW INTERNATIONAL INC   426.880
# 67690  006557 1985-08-31   1985    8  LAIDLAW INTERNATIONAL INC   652.477
# 67691  006557 1986-08-31   1986    8  LAIDLAW INTERNATIONAL INC   901.769
# 67692  006557 1987-08-31   1987    8  LAIDLAW INTERNATIONAL INC  1655.019
# 67693  006557 1988-08-31   1988    8  LAIDLAW INTERNATIONAL INC  1636.927
# 67694  006557 1989-08-31   1989    8  LAIDLAW INTERNATIONAL INC  2651.276
# 67695  006557 1995-08-31   1995    8  LAIDLAW INTERNATIONAL INC  4286.300
# 67696  006557 1996-08-31   1996    8  LAIDLAW INTERNATIONAL INC  4932.300
# 67697  006557 1997-08-31   1997    8  LAIDLAW INTERNATIONAL INC  6117.100
# 67698  006557 1998-08-31   1998    8  LAIDLAW INTERNATIONAL INC  6184.600
# 67699  006557 1999-08-31   1999    8  LAIDLAW INTERNATIONAL INC  5754.300
# 67700  006557 2000-08-31   2000    8  LAIDLAW INTERNATIONAL INC  4000.100
# 67701  006557 2001-08-31   2001    8  LAIDLAW INTERNATIONAL INC  4209.800
# 67702  006557 2002-08-31   2002    8  LAIDLAW INTERNATIONAL INC  4091.100
# 67703  006557 2003-08-31   2003    8  LAIDLAW INTERNATIONAL INC  3852.700
# 67704  006557 2004-08-31   2004    8  LAIDLAW INTERNATIONAL INC  3905.200
# 67705  006557 2005-08-31   2005    8  LAIDLAW INTERNATIONAL INC  2908.700
# 67706  006557 2006-08-31   2006    8  LAIDLAW INTERNATIONAL INC  3038.700

# %%
# How to deal with duplicates? Keep last available entry (datadate)
compa.dropna(subset=['fyear'], inplace=True)
compa.sort_values(['gvkey','fyear','at'], inplace=True)
compa = compa[~compa.duplicated(['gvkey', 'fyear'], keep='first')]

# %%
# Always check your result
compa.duplicated(['gvkey', 'fyear']).sum()
# Out:
# 0

# %% [markdown]
# ## Calculate Variables of Interest

# %% [markdown]
# ### Book Equity
#
# Daniel, Mota, Rottke, Santos (RFS, 2020) BE definition:
#
# Stockholders book equity, minus the book value of preferred stock, plus balance sheet deferred taxes (if available and fiscal year is < 1993), minus investment tax credit (if available), minus post-retirement benefit assets (PRBA) if available.
#
# Stockholders book equity is shareholder equity (SEQ), common equity (CEQ) plus preferred stock (PSTK) or total
# assets (AT) minus liabilities (LT) plus minority interest (MIB, if available) (depending on availability, in that order).
#
# Book value of preferred stock is redemption (PSTKRV), liquidation (PSTKL), or par value (PSTK) (depending on availability, in that order).
#
# Deferred taxes is deferred taxes and investment tax credit (TXDITC) or deferred taxes and investment tax credit (TXDB) plus investment tax credit (ITCB) (depending on availability, in that order).

# %%
# Calculating BE
# Shareholder Equity
compa['se'] = compa['seq']

# Uses Common Equity (ceq) + Preferred Stock (pstk) if SEQ is missing:
compa['se'] = compa['se'].fillna(compa['ceq'] + compa['pstk'])

# Uses Total Assets (at) - Liabilities (lt) + Minority Interest (mib, if available), if others are missing
compa['se'] = compa['se'].fillna(compa['at'] - compa['lt'] + compa['mib'].fillna(0))

# %%
# Preferred Stock
# Preferred Stock (Redemption Value)
compa['ps'] = compa['pstkrv']
# Uses Preferred Stock (Liquidating Value (pstkl)) if Preferred Stock (Redemption Value) is missing
compa['ps'] = compa['ps'].fillna(compa['pstkl'])
# Uses Preferred Stock (Carrying Value (pstk)) if others are missing
compa['ps'] = compa['ps'].fillna(compa['pstk'])

# %%
# Deferred Taxes
# Uses Deferred Taxes and Investment Tax Credit (txditc)
compa['dt'] = compa['txditc']

# This was Novy-Marx old legacy code. We drop this part to be in accordance with Ken French.
# Uses Deferred Taxes and Investment Tax Credit(txdb) + Investment Tax Credit (Balance Sheet) (itcb) if txditc is missing
compa['dt'] = compa['dt'].fillna(compa['txdb'].fillna(0) + compa['itcb'].fillna(0))
# If all measures are missing, set n  to missing
compa.loc[pd.isnull(compa['txditc']) & pd.isnull(compa['txdb']) & pd.isnull(compa['itcb']), 'dt'] = np.nan

compa.loc[compa['fyear'] >= 1993, 'dt'] = 0

# %%
# Book Equity
# Book Equity (BE) = Share Equity (se) - Prefered Stocks (ps) + Deferred Taxes (dt)
compa['be'] = (compa['se']  # shareholder equity must be available, otherwise BE is missing
               - compa['ps']  # preferred stock must be available, otherwise BE is missing
               + compa['dt'].fillna(0))  # add deferred taxes if available
               #- compa['prba'].fillna(0))  # subtract postretirement benefit assets if available

# %% [markdown]
# **Always look at your data...**

# %%
# Missings
compa.be.isnull().mean()
# Out:
# 0.19099685585295065

# %%
compa.be.hist()
# Out:
# <Axes: >

# %%
# Does it make sense to have a negative BE?
(compa.be<0).mean()
# Out:
# 0.09559416317316995

# %%
compa[compa.be>0].be.hist()
# Out:
# <Axes: >

# %%
compa[(compa.be>0)&(compa.be<10e3)&(compa.fyear==2017)].be.hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Operating Profitability (OPBE)
#
# Daniel, Mota, Rottke, Santos (RFS, 2020) OPBE definition:
#
# Operating profits to book equity (BE) ratio.
#
# Operating profits is sales (SALE) minus cost of goods sold (COGS), minus selling, general, and administrative expenses (XSGA),
# minus interest expense (XINT). In order to be non-missing, SALE must be non-missing, at least one of the other entries must be non-missing and BE must be greater than zero.

# %%
# COST = COGS + XSGA + XINT 
compa['cost'] = compa[['cogs', 'xsga', 'xint']].sum(axis=1, skipna=True)
compa.loc[compa[['cogs', 'xsga', 'xint']].isnull().all(axis=1), 'cost'] = np.nan

# %%
# OP = SALE -COST    
compa['op'] = compa['sale']-compa['cost']

# %% [markdown]
# **Always look at your data...**

# %%
# Look at missings
compa.op.isnull().mean()
# Out:
# 0.1946569654950016

# %%
compa[compa.fyear==2017].op.hist()
# Out:
# <Axes: >

# %%
# Which was the most profitable company in 2023?
compa.loc[compa[compa.fyear==2023].op.idxmax(),['gvkey','conm','op','be','at']]
# Out:
# gvkey                002176
# conm     BERKSHIRE HATHAWAY
# op                 129379.0
# be                 561273.0
# at                1069978.0
# Name: 14394, dtype: object

# %%
# Plot
compa[compa.gvkey=='001690'].set_index('fyear').op.plot(title = "Apple's OP", grid=True)
# Out:
# <Axes: title={'center': "Apple's OP"}, xlabel='fyear'>

# %%
# Calculate OPBE
compa.loc[(compa.be > 0), 'opbe'] = compa['op']/compa['be']

# %% [markdown]
# **What do we do now?**

# %% [markdown]
# Look at the data...

# %%
# Look at missings
compa.opbe.isnull().mean()
# Out:
# 0.2917909545307965

# %%
# Be careful with ratios
compa.opbe.hist()
# Out:
# <Axes: >

# %%
# Plot
compa[compa.gvkey=='001690'].set_index('fyear').opbe.plot(title = "Apple's OPBE", grid=True)
# Out:
# <Axes: title={'center': "Apple's OPBE"}, xlabel='fyear'>

# %%
# plot op, be, and op/be on log scale and see difference
compa[compa.gvkey=='001690'].set_index('fyear')[['op', 'be', 'opbe']].plot(label = ["Apple's OPBE"], grid=True, logy=True)
# Out:
# <Axes: xlabel='fyear'>

# %% [markdown]
# ### Investment (INV)
#
# Daniel, Mota, Rottke, Santos (RFS, 2020) INV definition:
#
# Total asset (AT) growth $(AT_t/AT_{t-1} - 1)$.
#
# We consider PERMCO as company's identification key. AT must be greater than zero to be not missing.

# %%
# Calculate lag assets and investment
compa.sort_values(['gvkey', 'fyear'], inplace=True)
compa['at_lag'] = compa.groupby('gvkey').at.shift(1)
compa['inv'] = (compa['at'] - compa['at_lag']) / compa['at_lag']

# %%
compa.loc[compa.at_lag==0, 'inv'] = np.nan

# %% [markdown]
# What if compa has missing years?

# %%
compa['fdiff'] = compa.groupby('gvkey').fyear.diff()

# %%
compa[(compa.fdiff>1)][['gvkey','fyear','fdiff', 'at','at_lag', 'inv']]
# Out:
#          gvkey  fyear  fdiff         at     at_lag        inv
# 22027   002820   2001    4.0    117.090        NaN        NaN
# 28048   003279   2011   19.0        NaN      1.269        NaN
# 30232   003469   2002    4.0    406.677        NaN        NaN
# 34228   003819   2011   19.0        NaN      2.295        NaN
# 36944   004049   2000    4.0    905.890        NaN        NaN
# 40175   004292   2012    3.0      0.704      0.534   0.318352
# 40733   004341   2000    2.0      0.000        NaN        NaN
# 41511   004412   2004    2.0    213.432    218.681  -0.024003
# 41515   004412   2008    2.0    219.640    203.755   0.077961
# 45343   004707   1996    3.0     14.416        NaN        NaN
# 51103   005202   1999   14.0      0.000      0.102  -1.000000
# 56622   005681   1995    4.0     26.851  13885.098  -0.998066
# 57931   005792   1998   13.0    218.462     84.850   1.574685
# 58398   005835   1997   16.0      0.030      3.052  -0.990170
# 60416   006000   2010   20.0        NaN      6.091        NaN
# 65973   006423   2011   22.0        NaN     38.823        NaN
# 66430   006464   1998   13.0      0.027      1.553  -0.982614
# 73466   007102   2011   19.0        NaN      1.687        NaN
# 74680   007185   2000    2.0    139.946    182.059  -0.231315
# 83012   007860   1998    2.0      0.423        NaN        NaN
# 87282   008145   2010   20.0        NaN     89.088        NaN
# 93133   008605   2001    3.0   2745.536        NaN        NaN
# 103053  009455   2007    4.0     17.965     20.144  -0.108171
# 103569  009493   2011   19.0        NaN      0.829        NaN
# 118436  010734   2019    4.0      2.992      3.784  -0.209302
# 119553  010820   2011   19.0        NaN      1.138        NaN
# 123555  011137   2011   20.0        NaN     75.795        NaN
# 125687  011332   1998   11.0      0.054      2.970  -0.981818
# 129294  011611   1997   15.0      0.007      1.041  -0.993276
# 132440  011878   2011   19.0        NaN      0.875        NaN
# 134965  012132   1998   10.0      0.000      1.311  -1.000000
# 135413  012161   2011   19.0        NaN     77.187        NaN
# 137072  012286   1996    6.0      0.839      1.293  -0.351121
# 137531  012324   2010   18.0        NaN      0.138        NaN
# 149493  013212   2011   20.0        NaN     16.418        NaN
# 155713  013712   2009    2.0   1580.300        NaN        NaN
# 156019  013744   1990    4.0        NaN      1.028        NaN
# 158135  013936   1998    2.0      0.016        NaN        NaN
# 158472  013958   2011   21.0        NaN  11310.898        NaN
# 158851  013973   2005    6.0    121.222    751.055  -0.838598
# 160043  014038   2011   20.0        NaN     24.309        NaN
# 162319  014186   2001    4.0    160.347        NaN        NaN
# 167267  014488   2011   20.0        NaN   3453.626        NaN
# 167952  014546   1985    2.0     55.660        NaN        NaN
# 168608  014582   1998    2.0      0.085        NaN        NaN
# 169129  014608   2011   21.0        NaN     43.322        NaN
# 170022  014660   2007    3.0        NaN        NaN        NaN
# 165952  014783   2004   10.0        NaN        NaN        NaN
# 172932  014955   1997    9.0      0.747      6.741  -0.889186
# 173388  014995   2007    3.0        NaN        NaN        NaN
# 178605  015355   2011   21.0        NaN     88.760        NaN
# 184249  016445   2005    8.0        NaN        NaN        NaN
# 184772  016482   2010   20.0        NaN      2.202        NaN
# 192921  017238   2010   20.0        NaN      1.816        NaN
# 194702  017616   1998    6.0    159.707        NaN        NaN
# 208249  020115   2012    4.0    440.908    325.075   0.356327
# 209746  020305   2000    4.0   4430.102    637.436   5.949877
# 212979  020704   1994    2.0     13.574        NaN        NaN
# 214167  020866   1991    2.0     82.200        NaN        NaN
# 219385  021829   2011   21.0        NaN      5.289        NaN
# 220035  021943   2017    2.0        NaN        NaN        NaN
# 221737  022251   2011   20.0        NaN      2.535        NaN
# 228888  023714   1998    3.0   1747.016    567.713   2.077287
# 236631  024683   2006    2.0        NaN        NaN        NaN
# 237325  024739   2006    2.0        NaN        NaN        NaN
# 237352  024741   1999    2.0      0.286        NaN        NaN
# 237869  024787   1998    5.0    328.283    172.455   0.903586
# 238100  024805   2007    3.0        NaN        NaN        NaN
# 241006  025064   2006    2.0        NaN        NaN        NaN
# 246160  025586   1998    3.0    231.130    285.850  -0.191429
# 246338  025597   2007    2.0        NaN        NaN        NaN
# 251754  026136   1992    2.0      3.003        NaN        NaN
# 253067  026379   2017    4.0     66.787    106.559  -0.373239
# 254274  026718   2000    3.0      1.983      0.302   5.566225
# 259271  027854   2007    2.0        NaN        NaN        NaN
# 260353  027947   2007    2.0        NaN        NaN        NaN
# 266942  028606   2006    2.0        NaN        NaN        NaN
# 269195  028826   2005    2.0        NaN        NaN        NaN
# 269368  028843   2007    3.0        NaN        NaN        NaN
# 269997  028903   2011    2.0   1370.560        NaN        NaN
# 270089  028911   2022    3.0        NaN        NaN        NaN
# 270837  029000   2004    7.0        NaN        NaN        NaN
# 275816  029513   2005    2.0        NaN    201.516        NaN
# 279422  029930   1999    2.0     71.801     98.245  -0.269164
# 284880  030616   1999    5.0      3.409      6.094  -0.440597
# 288470  031135   1996    2.0        NaN     69.589        NaN
# 290942  031533   2008    3.0    133.555    139.138  -0.040126
# 297630  033291   2023    4.0        NaN        NaN        NaN
# 303184  035190   2021    2.0        NaN        NaN        NaN
# 303236  035205   2021    2.0        NaN        NaN        NaN
# 312010  038318   2023    2.0        NaN        NaN        NaN
# 312011  038318   2025    2.0        NaN        NaN        NaN
# 312015  038319   2025    2.0        NaN        NaN        NaN
# 312018  038320   2024    2.0        NaN        NaN        NaN
# 328342  061163   2003    2.0   1364.942        NaN        NaN
# 331375  061572   2004    4.0    288.040        NaN        NaN
# 332512  061697   2002    2.0    350.082    298.277   0.173681
# 333044  061745   2008    3.0    514.582        NaN        NaN
# 347460  064020   2005    2.0      0.409        NaN        NaN
# 350760  064545   2007    3.0        NaN        NaN        NaN
# 351047  064582   2007    7.0        NaN     62.376        NaN
# 352228  064745   2002    4.0    590.351    714.027  -0.173209
# 356251  065275   2010    3.0   1721.692    454.513   2.787993
# 358345  065581   2009    9.0   6898.722  14374.897  -0.520085
# 360124  065819   2000    2.0    405.504        NaN        NaN
# 360770  065916   1995    3.0     14.934        NaN        NaN
# 363972  066522   2007    2.0        NaN        NaN        NaN
# 354648  066557   2006    2.0      1.213      6.575  -0.815513
# 365217  066728   1998    2.0     23.290        NaN        NaN
# 370030  106041   2004    5.0      0.541      3.435  -0.842504
# 370325  106133   2006    2.0        NaN        NaN        NaN
# 371128  106466   2007    2.0     77.694        NaN        NaN
# 377298  109921   2006    2.0        NaN        NaN        NaN
# 378312  110804   2005    2.0    360.385        NaN        NaN
# 379391  111873   2010    3.0    501.991    342.546   0.465470
# 391546  124039   2012    2.0        NaN        NaN        NaN
# 394992  126697   2012    2.0        NaN        NaN        NaN
# 396614  129087   2012    2.0        NaN        NaN        NaN
# 396626  129098   2012    2.0        NaN        NaN        NaN
# 397994  132981   2008    2.0      5.072        NaN        NaN
# 398358  133346   2005    2.0        NaN        NaN        NaN
# 399861  135249   2012    2.0        NaN        NaN        NaN
# 401544  137139   2012    2.0        NaN        NaN        NaN
# 401561  137143   2012    2.0        NaN        NaN        NaN
# 403891  138981   1998    3.0     33.025        NaN        NaN
# 404427  140032   2012    2.0        NaN        NaN        NaN
# 408064  142130   2007    2.0        NaN        NaN        NaN
# 408272  142253   2012    2.0        NaN        NaN        NaN
# 409766  143466   2012    2.0        NaN        NaN        NaN
# 409934  143710   2008    4.0    301.039    366.894  -0.179493
# 410676  144217   2020    2.0        NaN        NaN        NaN
# 410700  144218   2020    2.0        NaN        NaN        NaN
# 410723  144219   2020    2.0        NaN        NaN        NaN
# 412420  145411   2006    2.0        NaN        NaN        NaN
# 412429  145412   2006    2.0        NaN        NaN        NaN
# 412473  145415   2006    2.0        NaN        NaN        NaN
# 414213  146616   2002    2.0     21.795      1.046  19.836520
# 418083  149265   2020    2.0        NaN        NaN        NaN
# 418106  149266   2020    2.0        NaN        NaN        NaN
# 420358  151199   2005    2.0        NaN        NaN        NaN
# 422245  154118   2011    2.0        NaN        NaN        NaN
# 422253  154118   2020    2.0        NaN        NaN        NaN
# 422882  154760   2004    2.0    276.587    243.784   0.134558
# 423280  155326   2006    2.0        NaN        NaN        NaN
# 424004  156520   2006    2.0        NaN        NaN        NaN
# 426236  157679   2011    4.0   3231.561        NaN        NaN
# 427944  160295   2004    2.0      7.969      0.313  24.460064
# 429210  160681   2010    4.0   1041.200        NaN        NaN
# 429627  160788   2011    5.0    118.869    133.503  -0.109616
# 429630  160788   2018    5.0    159.077    123.674   0.286261
# 429906  160865   2002    3.0  63186.000  15843.000   2.988260
# 434523  163595   2005    2.0     48.185        NaN        NaN
# 435463  163863   2013    5.0        NaN   1402.943        NaN
# 437157  164363   2010    2.0   1097.900        NaN        NaN
# 440680  165878   2006    2.0    168.231     76.986   1.185215
# 444210  175226   2017    3.0        NaN        NaN        NaN
# 459923  178303   2015    2.0        NaN      0.246        NaN
# 460373  178482   2018    6.0      0.000      1.615  -1.000000
# 460614  178540   2011    5.0   1676.700   1889.900  -0.112810
# 464013  179313   2021    2.0        NaN        NaN        NaN
# 465035  179671   2009    3.0    103.469     87.780   0.178731
# 465899  180016   2009    2.0   3083.156   2925.031   0.054059
# 467485  180636   2007    2.0    105.146        NaN        NaN
# 488673  196856   2013    3.0        NaN      3.891        NaN
# 490762  221237   2005    2.0    613.738    172.843   2.550841
# 491434  233149   2007    2.0    163.373    119.603   0.365961
# 491441  233491   2009    2.0    453.331    707.883  -0.359596
# 492640  260850   2020    2.0        NaN        NaN        NaN
# 493411  265008   2008    2.0   1405.940    399.094   2.522829
# 495944  333359   2024    2.0        NaN        NaN        NaN

# %%
# Check one case of skipping years
compa.loc[compa.gvkey=='005681',['gvkey','fyear','at','at_lag','inv','fdiff']]
# Out:
#         gvkey  fyear         at     at_lag       inv  fdiff
# 56613  005681   1983   6803.074        NaN       NaN    NaN
# 56614  005681   1984   8885.500   6803.074  0.306101    1.0
# 56615  005681   1985  10018.598   8885.500  0.127522    1.0
# 56616  005681   1986  12074.598  10018.598  0.205218    1.0
# 56617  005681   1987  14109.098  12074.598  0.168494    1.0
# 56618  005681   1988  17008.699  14109.098  0.205513    1.0
# 56619  005681   1989  17766.699  17008.699  0.044565    1.0
# 56620  005681   1990  18259.500  17766.699  0.027737    1.0
# 56621  005681   1991  13885.098  18259.500 -0.239569    1.0
# 56622  005681   1995     26.851  13885.098 -0.998066    4.0
# 56623  005681   1996     17.091     26.851 -0.363487    1.0
# 56624  005681   1997     15.457     17.091 -0.095606    1.0
# 56625  005681   1998     19.043     15.457  0.231998    1.0
# 56626  005681   1999     27.528     19.043  0.445571    1.0
# 56627  005681   2000     24.818     27.528 -0.098445    1.0
# 56628  005681   2001     25.804     24.818  0.039729    1.0
# 56630  005681   2002    117.043     25.804  3.535847    1.0
# 56631  005681   2003    217.010    117.043  0.854105    1.0
# 56632  005681   2004    211.487    217.010 -0.025450    1.0
# 56633  005681   2005    294.261    211.487  0.391390    1.0
# 56634  005681   2006    237.299    294.261 -0.193576    1.0
# 56635  005681   2007    219.255    237.299 -0.076039    1.0
# 56636  005681   2008    190.397    219.255 -0.131618    1.0
# 56637  005681   2009    185.704    190.397 -0.024648    1.0
# 56638  005681   2010    184.510    185.704 -0.006430    1.0
# 56639  005681   2011    188.753    184.510  0.022996    1.0
# 56640  005681   2012    189.409    188.753  0.003475    1.0
# 56642  005681   2013    204.402    189.409  0.079157    1.0
# 56643  005681   2014    433.189    204.402  1.119299    1.0
# 56644  005681   2015    555.311    433.189  0.281914    1.0
# 56645  005681   2016    582.332    555.311  0.048659    1.0
# 56646  005681   2017    607.947    582.332  0.043987    1.0
# 56647  005681   2018    594.008    607.947 -0.022928    1.0

# %%
# Input missings
filter_inv = (compa['at']<=0)|(compa['at_lag']<=0)|(compa.fdiff>1)
compa.loc[filter_inv,['inv']] = np.nan
del(filter_inv)

# %%
# Check one case of skipping years (again)
compa.loc[compa.gvkey=='005681',['gvkey','fyear','at','at_lag','inv']]
# Out:
#         gvkey  fyear         at     at_lag       inv
# 56613  005681   1983   6803.074        NaN       NaN
# 56614  005681   1984   8885.500   6803.074  0.306101
# 56615  005681   1985  10018.598   8885.500  0.127522
# 56616  005681   1986  12074.598  10018.598  0.205218
# 56617  005681   1987  14109.098  12074.598  0.168494
# 56618  005681   1988  17008.699  14109.098  0.205513
# 56619  005681   1989  17766.699  17008.699  0.044565
# 56620  005681   1990  18259.500  17766.699  0.027737
# 56621  005681   1991  13885.098  18259.500 -0.239569
# 56622  005681   1995     26.851  13885.098       NaN
# 56623  005681   1996     17.091     26.851 -0.363487
# 56624  005681   1997     15.457     17.091 -0.095606
# 56625  005681   1998     19.043     15.457  0.231998
# 56626  005681   1999     27.528     19.043  0.445571
# 56627  005681   2000     24.818     27.528 -0.098445
# 56628  005681   2001     25.804     24.818  0.039729
# 56630  005681   2002    117.043     25.804  3.535847
# 56631  005681   2003    217.010    117.043  0.854105
# 56632  005681   2004    211.487    217.010 -0.025450
# 56633  005681   2005    294.261    211.487  0.391390
# 56634  005681   2006    237.299    294.261 -0.193576
# 56635  005681   2007    219.255    237.299 -0.076039
# 56636  005681   2008    190.397    219.255 -0.131618
# 56637  005681   2009    185.704    190.397 -0.024648
# 56638  005681   2010    184.510    185.704 -0.006430
# 56639  005681   2011    188.753    184.510  0.022996
# 56640  005681   2012    189.409    188.753  0.003475
# 56642  005681   2013    204.402    189.409  0.079157
# 56643  005681   2014    433.189    204.402  1.119299
# 56644  005681   2015    555.311    433.189  0.281914
# 56645  005681   2016    582.332    555.311  0.048659
# 56646  005681   2017    607.947    582.332  0.043987
# 56647  005681   2018    594.008    607.947 -0.022928

# %% [markdown]
# **What do we do now?**

# %%
# Look at missings
compa.inv.isnull().mean()
# Out:
# 0.2645759432441148

# %%
compa.inv.max()
# Out:
# 11492999.0

# %%
compa.inv.min()
# Out:
# -0.9999992483516351

# %%
# Be careful with ratios
compa.loc[compa.inv.idxmax(axis=0),['gvkey','conm','fyear','at','at_lag','inv']]
# Out:
# gvkey                          039128
# conm      BROOKFIELD WEALTH SOLUTIONS
# fyear                            2021
# at                            11493.0
# at_lag                          0.001
# inv                        11492999.0
# Name: 314294, dtype: object

# %%
 # What explains such large inv?
compa[compa.inv<10].inv.hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Is Asset Growth Investment?
#
# * See Cooper, Gulen, Schill, JF (2008);
# * What is asset growth capturing other than investment?
#     * Mergers;
#     * Issuance;
#     * Spin-offs.
# * Is it really investments that forecast future stock returns?

# %%
# A more traditional measure of investment: CAPX
compa['inv_capx'] = compa['capx']/compa['at_lag']
filter_inv_capx = (compa['capx']<=0)|(compa['at_lag']<=0)|(compa.fdiff>1)
compa.loc[filter_inv_capx,'inv_capx']=np.nan

# %%
# Difference for Apple
compa.loc[(compa.gvkey=='001690')&
          (compa.fyear>=1985),['fyear','inv','inv_capx']
         ].set_index(['fyear']).plot(title="Apple's Investment")
# Out:
# <Axes: title={'center': "Apple's Investment"}, xlabel='fyear'>

# %%
compa.loc[(compa.gvkey=='001690')&
          (compa.fyear>=1985),
          ['fyear','inv_capx']
         ].set_index(['fyear']).plot(title="Apple's Investment")
# Out:
# <Axes: title={'center': "Apple's Investment"}, xlabel='fyear'>

# %% [markdown]
# ## Save Output

# %%
compa.columns
# Out:
# Index(['gvkey', 'datadate', 'conm', 'tic', 'cusip', 'fyear', 'fyr', 'at',
#        'capx', 'ceq', 'cogs', 'csho', 'dlc', 'dlcch', 'dltt', 'dp', 'ib',
#        'itcb', 'lt', 'mib', 'naicsh', 'ni', 'prstkcc', 'pstk', 'pstkl',
#        'pstkrv', 're', 'revt', 'sale', 'seq', 'sich', 'txdb', 'txdi', 'txditc',
#        'wcapch', 'xint', 'xlr', 'xrd', 'xsga', 'se', 'ps', 'dt', 'be', 'cost',
#        'op', 'opbe', 'at_lag', 'inv', 'fdiff', 'inv_capx'],
#       dtype='object')

# %%
compa.to_pickle(path='./compa_annual.pkl')
